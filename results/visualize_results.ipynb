# %%
import plotly.graph_objects as go

import numpy as np
import pandas as pd

from scipy import signal

# %%
r_eval = pd.read_csv('aliens_3tl_eval_reward.csv', sep=',', header=0)
r_eval = r_eval.drop(columns="Wall time")

r_train = pd.read_csv('aliens_3tl_mean_reward.csv', sep=',', header=0)
r_train = r_train.drop(columns="Wall time")

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x = r_eval['Step'],
    y = signal.savgol_filter(r_eval['Value'], 53, 4),
    # y = r_eval['Value'],
    mode='lines',
    line=go.scatter.Line(color="red"),
    name='Eval'
))

fig.add_trace(go.Scatter(
    x=r_train['Step'],
    y=signal.savgol_filter(r_train['Value'], 53, 4), 
    # y = r_train['Value'],
    mode='lines',
    line=go.scatter.Line(color="blue"),
    name='Train'
))


fig.show()
# Out:
# <div>
#
#
#             <div id="15d0ed48-512f-4abf-bfad-ca93832095c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("15d0ed48-512f-4abf-bfad-ca93832095c6")) {
#                     Plotly.newPlot(
#                         '15d0ed48-512f-4abf-bfad-ca93832095c6',
#                         [{"line": {"color": "red"}, "mode": "lines", "name": "Eval", "type": "scatter", "x": [11264, 21504, 31744, 41984, 52224, 62464, 72704, 82944, 93184, 103424, 113664, 123904, 134144, 144384, 154624, 164864, 175104, 185344, 195584, 205824, 216064, 226304, 236544, 246784, 257024, 267264, 277504, 287744, 297984, 308224, 318464, 328704, 338944, 349184, 359424, 369664, 379904, 390144, 400384, 410624, 420864, 431104, 441344, 451584, 461824, 472064, 482304, 492544, 502784, 513024, 523264, 533504, 543744, 553984, 564224, 574464, 584704, 594944, 605184, 615424, 625664, 635904, 646144, 656384, 666624, 676864, 687104, 697344, 707584, 717824, 728064, 738304, 748544, 758784, 769024, 779264, 789504, 799744, 809984, 820224, 830464, 840704, 850944, 861184, 871424, 881664, 891904, 902144, 912384, 922624, 932864, 943104, 953344, 963584, 973824, 984064, 994304, 1004544, 1014784, 1025024, 1035264, 1045504, 1055744, 1065984, 1076224, 1086464, 1096704, 1106944, 1117184, 1127424, 1137664, 1147904, 1158144, 1168384, 1178624, 1188864, 1199104, 1209344, 1219584, 1229824, 1240064, 1250304, 1260544, 1270784, 1281024, 1291264, 1301504, 1311744, 1321984, 1332224, 1342464, 1352704, 1362944, 1373184, 1383424, 1393664, 1403904, 1414144, 1424384, 1434624, 1444864, 1455104, 1465344, 1475584, 1485824, 1496064, 1506304, 1516544, 1526784, 1537024, 1547264, 1557504, 1567744, 1577984, 1588224, 1598464, 1608704, 1618944, 1629184, 1639424, 1649664, 1659904, 1670144, 1680384, 1690624, 1700864