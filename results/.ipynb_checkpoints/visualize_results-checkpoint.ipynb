# %%
import plotly.graph_objects as go

import numpy as np
import pandas as pd

from scipy import signal

# %% [markdown]
# # Aliens

# %%
r_eval_3tl = pd.read_csv('csv/aliens_3tl_eval_reward.csv', sep=',', header=0)
r_train_3tl = pd.read_csv('csv/aliens_3tl_mean_reward.csv', sep=',', header=0)

r_eval_2tl = pd.read_csv('csv/aliens_2tl_eval_reward.csv', sep=',', header=0)
r_train_2tl = pd.read_csv('csv/aliens_2tl_mean_reward.csv', sep=',', header=0)

r_eval_1tl = pd.read_csv('csv/aliens_1tl_eval_reward.csv', sep=',', header=0)
r_train_1tl = pd.read_csv('csv/aliens_1tl_mean_reward.csv', sep=',', header=0)

# %%
r_eval_3tl[r_eval_3tl['Value']==r_eval_3tl['Value'].max()]
# Out:
#         Wall time     Step      Value
# 192  1.575213e+09  1977344  44.900002

# %%
r_eval_2tl[r_eval_2tl['Value']==r_eval_2tl['Value'].max()]
# Out:
#         Wall time     Step      Value
# 278  1.575246e+09  2847744  47.099998

# %%
r_eval_1tl[r_eval_1tl['Value']==r_eval_1tl['Value'].max()]
# Out:
#         Wall time     Step      Value
# 289  1.575247e+09  2960384  49.599998

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x = r_eval_1tl['Step'],
    # y = signal.savgol_filter(r_eval_1tl['Value'], 53, 1),
    y = r_eval_1tl['Value'],
    mode = 'lines',
    line = go.scatter.Line(color="red"),
    showlegend=False
))

fig.add_trace(go.Scatter(
    x = r_train_1tl['Step'],
    # y = signal.savgol_filter(r_train_1tl['Value'], 53, 1), 
    y = r_train_1tl['Value'],
    mode = 'lines',
    line = go.scatter.Line(color="blue"),
    showlegend=False
))

fig.show()
# Out:
# <div>
#
#
#             <div id="38434923-2edb-4079-847b-eba68afbf534" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("38434923-2edb-4079-847b-eba68afbf534")) {
#                     Plotly.newPlot(
#                         '38434923-2edb-4079-847b-eba68afbf534',
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x = r_eval_2tl['Step'],
    y = signal.savgol_filter(r_eval_2tl['Value'], 53, 1),
    mode = 'lines',
    line = go.scatter.Line(color="red"),
    showlegend=False
))

fig.add_trace(go.Scatter(
    x = r_train_2tl['Step'],
    y = signal.savgol_filter(r_train_2tl['Value'], 53, 1), 
    mode = 'lines',
    line = go.scatter.Line(color="blue"),
    showlegend=False
))

fig.show()
# Out:
# <div>
#
#
#             <div id="fb1a7790-8110-4c80-93e7-cbf7e863d776" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fb1a7790-8110-4c80-93e7-cbf7e863d776")) {
#                     Plotly.newPlot(
#                         'fb1a7790-8110-4c80-93e7-cbf7e863d776',
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x = r_eval_3tl['Step'],
    y = signal.savgol_filter(r_eval_3tl['Value'], 53, 1),
    mode = 'lines',
    line = go.scatter.Line(color="red"),
    showlegend=False
))

fig.add_trace(go.Scatter(
    x = r_train_3tl['Step'],
    y = signal.savgol_filter(r_train_3tl['Value'], 53, 1), 
    mode = 'lines',
    line = go.scatter.Line(color="blue"),
    showlegend=False
))

fig.show()
# Out:
# <div>
#
#
#             <div id="7bec3b6c-6c6d-4ac8-9462-74eca7df04a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7bec3b6c-6c6d-4ac8-9462-74eca7df04a9")) {
#                     Plotly.newPlot(
#                         '7bec3b6c-6c6d-4ac8-9462-74eca7df04a9',
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x = r_train_3tl['Step'],
    y = signal.savgol_filter(r_train_3tl['Value'], 53, 3),
    mode = 'lines',
    line = go.scatter.Line(color="red"),
    name = '3 fases de treinamento'
))

fig.add_trace(go.Scatter(
    x = r_train_2tl['Step'],
    y = signal.savgol_filter(r_train_2tl['Value'], 53, 3), 
    mode = 'lines',
    line = go.scatter.Line(color="blue"),
    name = '2 fases de treinamento'
))

fig.add_trace(go.Scatter(
    x = r_train_1tl['Step'],
    y = signal.savgol_filter(r_train_1tl['Value'], 53, 3), 
    mode = 'lines',
    line = go.scatter.Line(color="green"),
    name = '1 fase de treinamento'
))

# ************************************************************

fig.add_trace(go.Scatter(
    x = r_eval_3tl['Step'],
    y = signal.savgol_filter(r_eval_3tl['Value'], 53, 3),
    mode = 'lines',
    line = go.scatter.Line(color='rgb(255,153,153)'),
    showlegend=False
))

fig.add_trace(go.Scatter(
    x = r_eval_2tl['Step'],
    y = signal.savgol_filter(r_eval_2tl['Value'], 53, 3), 
    mode = 'lines',
    line = go.scatter.Line(color='rgb(153,187,255)'),
    showlegend=False
))

fig.add_trace(go.Scatter(
    x = r_eval_1tl['Step'],
    y = signal.savgol_filter(r_eval_1tl['Value'], 53, 3), 
    mode = 'lines',
    line = go.scatter.Line(color='rgb(43,255,0)'),
    showlegend=False
))

fig.show()
# Out:
# <div>
#
#
#             <div id="e818ed30-6567-4da6-8fac-f289b64ff79d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e818ed30-6567-4da6-8fac-f289b64ff79d")) {
#                     Plotly.newPlot(
#                         'e818ed30-6567-4da6-8fac-f289b64ff79d',
# ...

# %%
xrandom = [44.52, 42.54, 42.86, 21.85, 38.3]
x1tl = [40.03, 38.19, 21.24, 17.47, 13.43]
x2tl = [40.82, 40.29, 29.2, 17.96, 27.0]
x3tl = [40.32, 40.88, 39.81, 19.64, 24.01]

# %% [markdown]
# # Boulder Dash

# %%
# r_eval_3tl = pd.read_csv('csv/missilecommand_3tl_eval_reward.csv', sep=',', header=0)
# r_train_3tl = pd.read_csv('csv/missilecommand_3tl_mean_reward.csv', sep=',', header=0)

# r_eval_2tl = pd.read_csv('csv/missilecommand_2tl_eval_reward.csv', sep=',', header=0)
# r_train_2tl = pd.read_csv('csv/missilecommand_2tl_mean_reward.csv', sep=',', header=0)

r_eval_1tl = pd.read_csv('csv/boulderdash_1tl_eval_reward.csv', sep=',', header=0)
r_train_1tl = pd.read_csv('csv/boulderdash_1tl_mean_reward.csv', sep=',', header=0)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x = r_eval_1tl['Step'],
    y = signal.savgol_filter(r_eval_1tl['Value'], 53, 1),
    mode = 'lines',
    line = go.scatter.Line(color="red"),
    showlegend=False
))

fig.add_trace(go.Scatter(
    x = r_train_1tl['Step'],
    y = signal.savgol_filter(r_train_1tl['Value'], 53, 1), 
    mode = 'lines',
    line = go.scatter.Line(color="blue"),
    showlegend=False
))

fig.show()
# Out:
# <div>
#
#
#             <div id="ecbcae93-19bf-418d-90e1-9ace07623514" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ecbcae93-19bf-418d-90e1-9ace07623514")) {
#                     Plotly.newPlot(
#                         'ecbcae93-19bf-418d-90e1-9ace07623514',
# ...

# %%
xrandom = [0.64, 2.28, 4.26, 0.25, 2.38]

# %% [markdown]
# # Missile Command

# %%
r_eval_3tl = pd.read_csv('csv/missilecommand_3tl_eval_reward.csv', sep=',', header=0)
r_train_3tl = pd.read_csv('csv/missilecommand_3tl_mean_reward.csv', sep=',', header=0)

r_eval_2tl = pd.read_csv('csv/missilecommand_2tl_eval_reward.csv', sep=',', header=0)
r_train_2tl = pd.read_csv('csv/missilecommand_2tl_mean_reward.csv', sep=',', header=0)

r_eval_1tl = pd.read_csv('csv/missilecommand_1tl_eval_reward.csv', sep=',', header=0)
r_train_1tl = pd.read_csv('csv/missilecommand_1tl_mean_reward.csv', sep=',', header=0)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x = r_eval_1tl['Step'],
    y = signal.savgol_filter(r_eval_1tl['Value'], 53, 1),
    mode = 'lines',
    line = go.scatter.Line(color="red"),
    showlegend=False
))

fig.add_trace(go.Scatter(
    x = r_train_1tl['Step'],
    y = signal.savgol_filter(r_train_1tl['Value'], 53, 1), 
    mode = 'lines',
    line = go.scatter.Line(color="blue"),
    showlegend=False
))

fig.show()
# Out:
# <div>
#
#
#             <div id="49f2db8d-5e6b-4f36-8dea-805139ef1acf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("49f2db8d-5e6b-4f36-8dea-805139ef1acf")) {
#                     Plotly.newPlot(
#                         '49f2db8d-5e6b-4f36-8dea-805139ef1acf',
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x = r_eval_2tl['Step'],
    y = signal.savgol_filter(r_eval_2tl['Value'], 53, 1),
    mode = 'lines',
    line = go.scatter.Line(color="red"),
    showlegend=False
))

fig.add_trace(go.Scatter(
    x = r_train_2tl['Step'],
    y = signal.savgol_filter(r_train_2tl['Value'], 53, 1), 
    mode = 'lines',
    line = go.scatter.Line(color="blue"),
    showlegend=False
))

fig.show()
# Out:
# <div>
#
#
#             <div id="5ed410ea-0654-4523-9ab1-5b254a07e82d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5ed410ea-0654-4523-9ab1-5b254a07e82d")) {
#                     Plotly.newPlot(
#                         '5ed410ea-0654-4523-9ab1-5b254a07e82d',
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x = r_eval_3tl['Step'],
    y = signal.savgol_filter(r_eval_3tl['Value'], 53, 1),
    mode = 'lines',
    line = go.scatter.Line(color="red"),
    showlegend=False
))

fig.add_trace(go.Scatter(
    x = r_train_3tl['Step'],
    y = signal.savgol_filter(r_train_3tl['Value'], 53, 1), 
    mode = 'lines',
    line = go.scatter.Line(color="blue"),
    showlegend=False
))

fig.show()
# Out:
# <div>
#
#
#             <div id="a4614ee1-22e5-48e4-84de-7690eeff8768" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a4614ee1-22e5-48e4-84de-7690eeff8768")) {
#                     Plotly.newPlot(
#                         'a4614ee1-22e5-48e4-84de-7690eeff8768',
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x = r_train_3tl['Step'],
    y = signal.savgol_filter(r_train_3tl['Value'], 53, 1),
    mode = 'lines',
    line = go.scatter.Line(color="red"),
    name = '3 fases de treinamento'
))

fig.add_trace(go.Scatter(
    x = r_train_2tl['Step'],
    y = signal.savgol_filter(r_train_2tl['Value'], 53, 1), 
    mode = 'lines',
    line = go.scatter.Line(color="blue"),
    name = '2 fases de treinamento'
))

fig.add_trace(go.Scatter(
    x = r_train_1tl['Step'],
    y = signal.savgol_filter(r_train_1tl['Value'], 53, 1), 
    mode = 'lines',
    line = go.scatter.Line(color="green"),
    name = '1 fase de treinamento'
))

fig.show()
# Out:
# <div>
#
#
#             <div id="9ad44ee4-dba8-49ba-bde8-5911fba9f1d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9ad44ee4-dba8-49ba-bde8-5911fba9f1d2")) {
#                     Plotly.newPlot(
#                         '9ad44ee4-dba8-49ba-bde8-5911fba9f1d2',
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x = r_train_3tl['Step'],
    y = signal.savgol_filter(r_train_3tl['Value'], 53, 3),
    mode = 'lines',
    line = go.scatter.Line(color="red"),
    name = '3 fases de treinamento'
))

fig.add_trace(go.Scatter(
    x = r_train_2tl['Step'],
    y = signal.savgol_filter(r_train_2tl['Value'], 53, 3), 
    mode = 'lines',
    line = go.scatter.Line(color="blue"),
    name = '2 fases de treinamento'
))

fig.add_trace(go.Scatter(
    x = r_train_1tl['Step'],
    y = signal.savgol_filter(r_train_1tl['Value'], 53, 3), 
    mode = 'lines',
    line = go.scatter.Line(color="green"),
    name = '1 fase de treinamento'
))

# ************************************************************

fig.add_trace(go.Scatter(
    x = r_eval_3tl['Step'],
    y = signal.savgol_filter(r_eval_3tl['Value'], 53, 1),
    mode = 'lines',
    line = go.scatter.Line(color='rgb(255,153,153)'),
    showlegend=False
))

fig.add_trace(go.Scatter(
    x = r_eval_2tl['Step'],
    y = signal.savgol_filter(r_eval_2tl['Value'], 53, 1), 
    mode = 'lines',
    line = go.scatter.Line(color='rgb(153,187,255)'),
    showlegend=False
))

fig.add_trace(go.Scatter(
    x = r_eval_1tl['Step'],
    y = signal.savgol_filter(r_eval_1tl['Value'], 53, 1), 
    mode = 'lines',
    line = go.scatter.Line(color='rgb(43,255,0)'),
    showlegend=False
))

fig.show()
# Out:
# <div>
#
#
#             <div id="d9e221e0-a630-4ebf-ad40-c07bf7568882" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d9e221e0-a630-4ebf-ad40-c07bf7568882")) {
#                     Plotly.newPlot(
#                         'd9e221e0-a630-4ebf-ad40-c07bf7568882',
# ...

# %%
xrandom = [-2.08, 2.82, -1.92, -1.96, -4.18]
x1tl = [3, 1.61, -1.56, -1.45, -2.8]
x2tl = [3, 7.69, -2.41, -1.75, -2.57]
x3tl = [4, 7.54, 0.79, -1.59, -1.32]
